# %%
# !pip install streamlit
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    ----------------- ---------------------- 3.9/9.2 MB 26.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 30.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/797.0 kB ? eta -:--:--
#    ---------------------------------------- 797.0/797.0 kB 33.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ------------------------------------ --- 10.2/11.3 MB 45.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 44.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/27.3 MB ? eta -:--:--
#    ---------------- ----------------------- 11.3/27.3 MB 54.0 MB/s eta 0:00:01
#    --------------------------------- ------ 22.8/27.3 MB 53.4 MB/s eta 0:00:01
#    ---------------------------------------- 27.3/27.3 MB 49.3 MB/s  0:00:00
# ...
#
#    ------------ ---------------------------  4/13 [pyarrow]
# ...

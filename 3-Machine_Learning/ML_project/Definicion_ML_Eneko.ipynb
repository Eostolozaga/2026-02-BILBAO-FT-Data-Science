# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Chess Opening Evaluator"

# %% [markdown]
# ### TEMA

# %% [markdown]
# # Describe brevemente el tema del proyecto en Markdown
# Este proyecto desarrolla un sistema de Machine Learning diseñado para analizar, clasificar y recomendar aperturas de ajedrez personalizadas. A diferencia de los motores de búsqueda tradicionales, el sistema utiliza algoritmos de aprendizaje no supervisado (Clustering) y aprendizaje basado en instancias (KNN) para identificar patrones de juego y similitudes entre posiciones teóricas y partidas reales.

# %% [markdown]
# ### OBJETIVOS

# %% [markdown]
# Define aquí el objetivo del proyecto

# %% [markdown]
# Proporcionar al jugador un repertorio inteligente basado en datos, que no solo sugiera qué jugar según la teoría, sino que se adapte a su estilo y rendimiento mediante el análisis de sus propias partidas y sugerencias personalizadas para trabajar los errores.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
# API DE LICHESS Y WEB SCRAPING (MODERN-CHESS,YOUTUBE,LIBROS INTERNET)

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\Eneko\Desktop\Ejercicios Data\Proyectos\Proyecto ML\master_dataset_ml.csv")
df2 = pd.read_csv(r"C:\Users\Eneko\Desktop\Ejercicios Data\Proyectos\Proyecto ML\src_manual.csv")
df3 = pd.read_csv(r"C:\Users\Eneko\Desktop\Ejercicios Data\Proyectos\Proyecto ML\src_modern_chess.csv")
df4 = pd.read_csv(r"C:\Users\Eneko\Desktop\Ejercicios Data\Proyectos\Proyecto ML\src_youtube.csv")

# %%
df1.head()
# Out:
#             Usuario  Rating_Usuario              Apertura    Color  \
# 0        stevobrine            1833      Philidor Defense  Blancas
# 1  tecojoytetruqueo            2360     Caro-Kann Defense  Blancas
# 2  tecojoytetruqueo            2360      Petrov's Defense  Blancas
# 3  tecojoytetruqueo            2360     Queen's Pawn Game   Negras
# 4  tecojoytetruqueo            2360  King's Indian Attack   Negras
#
#    Fin_Teoria  ACL_Post_Teo  Victoria   Game_ID
# 0           7         219.0       0.0       NaN
# 1          15         136.0       1.0  JeARD20g
# 2          17          73.0       0.0  RaSGXBJe
# 3           9         129.3       0.0  DH2yl6ve
# 4          15           4.0       1.0  5i9zdJLz

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2854 entries, 0 to 2853
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Usuario         2854 non-null   object
#  1   Rating_Usuario  2854 non-null   int64
#  2   Apertura        2854 non-null   object
#  3   Color           2854 non-null   object
#  4   Fin_Teoria      2854 non-null   int64
#  5   ACL_Post_Teo    2854 non-null   float64
#  6   Victoria        2854 non-null   float64
#  7   Game_ID         2853 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 178.5+ KB

# %%
df2.head()
# Out:
#                              resource_id  source  \
# 0                         man__my_system  manual
# 1                man__chess_fundamentals  manual
# 2        man__dvoretsky_s_endgame_manual  manual
# 3  man__silman_s_complete_endgame_course  manual
# 4             man__winning_chess_tactics  manual
#
#                               title  \
# 0                         My System
# 1                Chess Fundamentals
# 2        Dvoretsky's Endgame Manual
# 3  Silman's Complete Endgame Course
# 4             Winning Chess Tactics
#
#                                                  url resource_type format  \
# 0   https://www.amazon.com/s?k=My+System+Nimzowitsch          book   text
# 1             https://www.gutenberg.org/ebooks/33370          book   text
# 2  https://www.amazon.com/s?k=Dvoretsky+Endgame+M...          book   text
# 3  https://www.amazon.com/s?k=Silman+Complete+End...          book   text
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   resource_id     13 non-null     object
#  1   source          13 non-null     object
#  2   title           13 non-null     object
#  3   url             13 non-null     object
#  4   resource_type   13 non-null     object
#  5   format          13 non-null     object
#  6   course_type     13 non-null     object
#  7   openings        2 non-null      object
#  8   color           13 non-null     object
#  9   author          13 non-null     object
#  10  author_title    0 non-null      float64
#  11  level_min       13 non-null     int64
#  12  level_max       13 non-null     int64
#  13  level_tier      13 non-null     object
#  14  duration_min    0 non-null      float64
#  15  price_eur       13 non-null     float64
#  16  is_free         13 non-null     int64
# ...

# %%
df3.head()
# Out:
#                                     resource_id        source  \
# 0          mc__chebanenko_slav_for_black_part_1  modern_chess
# 1               mc__inside_your_games_edition_4  modern_chess
# 2  mc__1_d4_nf6_2_nf3_g6_3_nbd2_deep_understand  modern_chess
# 3  mc__french_steinitz_with_rb8_repertoire_for_  modern_chess
# 4  mc__kings_indian_defense_repertoire_for_blac  modern_chess
#
#                                                title  \
# 0                 Chebanenko Slav for Black - Part 1
# 1            Inside Your Games - Edition 4Discounted
# 2  1.d4 Nf6 2.Nf3 g6 3.Nbd2 - Deep UnderstandingD...
# 3  French Steinitz with ...Rb8 - Repertoire for B...
# 4  King's Indian Defense: Repertoire for Black - ...
#
#                                                  url resource_type format  \
# 0  https://www.modern-chess.com/course/chebanenko...        course  video
# 1  https://www.modern-chess.com/course/inside-you...        course  video
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   resource_id     825 non-null    object
#  1   source          825 non-null    object
#  2   title           825 non-null    object
#  3   url             825 non-null    object
#  4   resource_type   825 non-null    object
#  5   format          825 non-null    object
#  6   course_type     825 non-null    object
#  7   openings        654 non-null    object
#  8   color           825 non-null    object
#  9   author          825 non-null    object
#  10  author_title    772 non-null    object
#  11  level_min       825 non-null    int64
#  12  level_max       825 non-null    int64
#  13  level_tier      825 non-null    object
#  14  duration_min    572 non-null    float64
#  15  price_eur       0 non-null      float64
#  16  is_free         825 non-null    int64
# ...

# %%
df4.head()
# Out:
#        resource_id   source  \
# 0  yt__qm4e7g2ruki  youtube
# 1  yt__0iayykxh3zc  youtube
# 2  yt__2miollk8dii  youtube
# 3  yt__6msbe_cahf4  youtube
# 4  yt__n2vdfnrwrfa  youtube
#
#                                                title  \
# 0    The Sicilian Defense | 10-Minute Chess Openings
# 1        DOMINATE as Black with the Sicilian Defense
# 2  Sicilian Defense ALL Variations Explained in 1...
# 3  BEST Chess Opening for Black: Sicilian Defense...
# 4   HOW TO PLAY SICILIAN DEFENSE!  Opening explained
#
#                                            url resource_type format  \
# 0  https://www.youtube.com/watch?v=qM4e7g2RukI         video  video
# 1  https://www.youtube.com/watch?v=0iAyyKxh3zc         video  video
# 2  https://www.youtube.com/watch?v=2miolLK8DiI         video  video
# 3  https://www.youtube.com/watch?v=6msbe_CAhf4         video  video
# 4  https://www.youtube.com/watch?v=n2vdFNrWrFA         video  video
#
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   resource_id     80 non-null     object
#  1   source          80 non-null     object
#  2   title           80 non-null     object
#  3   url             80 non-null     object
#  4   resource_type   80 non-null     object
#  5   format          80 non-null     object
#  6   course_type     80 non-null     object
#  7   openings        80 non-null     object
#  8   color           80 non-null     object
#  9   author          80 non-null     object
#  10  author_title    0 non-null      float64
#  11  level_min       80 non-null     int64
#  12  level_max       80 non-null     int64
#  13  level_tier      80 non-null     object
#  14  duration_min    0 non-null      float64
#  15  price_eur       80 non-null     float64
#  16  is_free         80 non-null     int64
# ...

# %% [markdown]
# ## Ejercicio descargas

# %% [markdown]
# Python es un lenguaje de propósito general, por lo que podemos desarrollar otros programas,
# aparte de ciencia de datos, que nos permitan montar dashboards, crear APIs o automatizar
# procesos. En este caso vas a automatizar un proceso, en el que tendrás que desarrollar un
# script que ordene todos los archivos de una carpeta, dependiendo de la extensión de los
# mismos.
#
#
# El objetivo es ordenar la típica carpeta de cajón desastre donde se nos acumulan archivos de
# todos los formatos como: imágenes, words, presentaciones, excels, ejecutables, zips, etc... Y
# que no vamos a ir viendo archivo a archivo, ordenándolos.... La solución suele ser eliminarlo
# todo. Vamos a intentar no tener que llegar a eso, ordenando los ficheros automáticamente en
# carpetas y revisar las que nos interesen. La típica carpeta donde aplicaríamos este programa es
# la de “Descargas”, donde se suelen acumular muchos archivos temporales.
#
#
# Por tanto, **el programa tiene que guardar los archivos de la carpeta “Descargas” (o cualquier
# otra donde acumules mucho archivo temporal) en los siguientes directorios dentro de la
# propia carpeta “Descargas”**:
# - Imagenes
# - Documentos
# - Software
# - Otros
#
# Cada vez que ejecutes el script, automáticamente se ordenarán todos los archivos en sus
# correspondientes carpetas.

# %% [markdown]
# ### 1. Crea un un programa con el flujo principal y encapsúlalo en funciones.

# %%
import os
import shutil

# %%
# --- CONFIGURACIÓN DE TIPOS ---
DOC_TYPES = ('.doc', '.docx', '.txt', '.pdf', '.xls', '.ppt', '.xlsx', '.pptx')
IMG_TYPES = ('.jpg', '.jpeg', '.png', '.svg', '.gif')
SOFTWARE_TYPES = ('.exe', '.py', '.ipynb')

def obtener_ruta_descargas():
    """Retorna la ruta de la carpeta de descargas del usuario actual."""
    return os.path.expanduser("~/Downloads")

def crear_carpetas_destino(ruta_base):
    """Crea las subcarpetas necesarias si no existen."""
    categorias = ["Imagenes", "Documentos", "Software", "Otros"]
    for nombre in categorias:
        ruta_completa = os.path.join(ruta_base, nombre)
        if not os.path.exists(ruta_completa):
            os.makedirs(ruta_completa)
    return categorias

def clasificar_archivo(nombre_archivo):
    """Determina a qué carpeta pertenece un archivo según su extensión."""
    nombre_low = nombre_archivo.lower()
    
    if nombre_low.endswith(IMG_TYPES):
        return "Imagenes"
    elif nombre_low.endswith(DOC_TYPES):
        return "Documentos"
    elif nombre_low.endswith(SOFTWARE_TYPES):
        return "Software"
    else:
        return "Otros"

def mover_archivos(ruta_base):
    """Recorre los archivos y los mueve a sus nuevas carpetas."""
    for item in os.listdir(ruta_base):
        ruta_origen = os.path.join(ruta_base, item)
        
        # Solo movemos archivos, ignoramos carpetas para evitar bucles
        if os.path.isfile(ruta_origen):
            carpeta_destino = clasificar_archivo(item)
            ruta_destino = os.path.join(ruta_base, carpeta_destino, item)
            
            shutil.move(ruta_origen, ruta_destino)
            print(f"Movido: {item} -> {carpeta_destino}")

def flujo_principal():
    """Coordina la ejecución de todas las funciones."""
    print("Iniciando organización de archivos...")
    
    # 1. Definir ruta
    ruta = obtener_ruta_descargas()
    
    # 2. Preparar el entorno (carpetas)
    crear_carpetas_destino(ruta)
    
    # 3. Ejecutar la acción
    mover_archivos(ruta)
    
    print("\n¡Proceso finalizado!")

if __name__ == "__main__":
    flujo_principal()
# Out:
# Iniciando organización de archivos...
# Movido: 0-Maps_with_Folium.ipynb -> Software
# Movido: 1_Intro_Pandas (1).ipynb -> Software
# Movido: 1_Intro_Pandas (2).ipynb -> Software
# Movido: 1_Intro_Pandas.ipynb -> Software
# Movido: 1_Numpy (1).ipynb -> Software
# Movido: 1_Numpy (2).ipynb -> Software
# Movido: 1_Numpy (3).ipynb -> Software
# Movido: 1_Numpy.ipynb -> Software
# Movido: 2-Estadística_descriptiva.ipynb -> Software
# Movido: 2_Null_Values.ipynb -> Software
# Movido: 3-Probabilidad.ipynb -> Software
# Movido: 3. Ejemplo de análisis exploratorio.ipynb -> Software
# Movido: 35101000 (1).XLS -> Documentos
# Movido: 35101000.XLS -> Documentos
# Movido: 3_Agrupaciones.ipynb -> Software
# Movido: 4_Combinar_Datasets.ipynb -> Software
# Movido: Ahorcado Eneko (1).ipynb -> Software
# Movido: Ahorcado Eneko (2).ipynb -> Software
# Movido: Ahorcado Eneko (3).ipynb -> Software
# Movido: Ahorcado Eneko (4).ipynb -> Software
# Movido: Ahorcado Eneko.ipynb -> Software
# ...

# %% [markdown]
# ### 2. Crea un programa standalone (main.py, funciones.py, variables.py) que realice la tarea sin necesidad de Jupyter notebooks.

# %%
# Importamos la función desde el archivo funciones.py
from funciones import organizar_archivos, preparar_entorno

# Ahora puedes ejecutar el flujo directamente en la celda
preparar_entorno()
total = organizar_archivos()

print(f"Proceso terminado. Archivos movidos: {total}")
# Out:
# Proceso terminado. Archivos movidos: 0
